# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %%
emp_data = pd.read_excel('C:\\Users\\abhi\\Desktop\\Employee project\\Data\\emp_performance.xls')

# %%
emp_data.shape
# Out:
# (1200, 28)

# %%
emp_data.head().T
# Out:
#                                             0                1  \
# EmpNumber                            E1001000         E1001006
# Age                                        32               47
# Gender                                   Male             Male
# EducationBackground                 Marketing        Marketing
# MaritalStatus                          Single           Single
# EmpDepartment                           Sales            Sales
# EmpJobRole                    Sales Executive  Sales Executive
# BusinessTravelFrequency         Travel_Rarely    Travel_Rarely
# DistanceFromHome                           10               14
# EmpEducationLevel                           3                4
# EmpEnvironmentSatisfaction                  4                4
# EmpHourlyRate                              55               42
# EmpJobInvolvement                           3                3
# EmpJobLevel                                 2                2
# ...

# %%
emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %% [markdown]
# # Column                -------------- Description​

# %%
# EmpNumber                   The Employee Id
# Age                         Age of the Employee
# Gender                      Gender of the Employee
# EducationBackground         Education of the Employee
# MaritalStatus               Whether the Employee is Married, Unmarried or Single
# EmpDepartment               Employee is from which department
# EmpJobRole                  The Job Role of the Employee
# BusinessTravelFrequency     How frequently the Employee travels for business 
# DistanceFromHome            How far the Employee resides from the office
# EmpEducationLevel           What the level of education of the Employee
# EmpEnvironmentSatisfaction  How satisfied is Employee with the office/job environment
# EmpHourlyRate               How much Employee gets paid per hour
# EmpJobInvolvement           What is the job involvement level of the Employee
# EmpJobLevel                 What is the Employee job level
# EmpJobSatisfaction          How satisfied the Employee is from the current job
# NumCompaniesWorked          How many companies has the Employee worked with
# OverTime                    Whether Employees does overtime?
# EmpLastSalaryHikePercent    How much percent salary hike did Employee receive last time
# EmpRelationshipSatisfaction How satisfied employee is with other Employees
# TotalWorkExperienceInYears  Total experience of the Employee in years
# TrainingTimesLastYear       How many trainings were conducted for the Employee last year
# EmpWorkLifeBalance          Level of Employee work life balance
# ExperienceYearsAtThisCompany Experience with the current company in years
# ExperienceYearsInCurrentRole Experience in current job role
# YearsSinceLastPromotion     How many years it has been without promotion
# YearsWithCurrManager        Number of years under current manager
# Attrition                   Whether the Employee leave or will be removed 
# PerformanceRating           The rating of the performance of Employee

# %%
# difference in mean and 50% indicates the skewness of the data

emp_data.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
emp_data[['Age','EmpJobSatisfaction','EmpEnvironmentSatisfaction']].head(10).value_counts()
# Out:
# Age  EmpJobSatisfaction  EmpEnvironmentSatisfaction
# 60   1                   1                             1
# 50   2                   4                             1
# 47   1                   4                             1
# 41   4                   2                             1
# 40   1                   4                             1
# 38   3                   3                             1
# 36   1                   1                             1
# 32   4                   4                             1
# 28   2                   1                             1
# 27   1                   4                             1
# dtype: int64

# %%
emp1 = emp_data[['EmpJobRole','EmpDepartment','YearsSinceLastPromotion','PerformanceRating']].head(50)
emp1
# Out:
#               EmpJobRole    EmpDepartment  YearsSinceLastPromotion  \
# 0        Sales Executive            Sales                        0
# 1        Sales Executive            Sales                        1
# 2        Sales Executive            Sales                        1
# 3                Manager  Human Resources                       12
# 4        Sales Executive            Sales                        2
# 5              Developer      Development                        1
# 6   Sales Representative            Sales                        2
# 7              Developer      Development                        3
# 8              Developer      Development                        0
# 9              Developer      Development                        0
# 10             Developer      Development                        1
# 11       Sales Executive            Sales                       11
# 12       Sales Executive            Sales                        7
# ...

# %%
emp_data['EmpEnvironmentSatisfaction'].value_counts()
# Out:
# 3    367
# 4    361
# 2    242
# 1    230
# Name: EmpEnvironmentSatisfaction, dtype: int64

# %%
# The performance rating is decreasing for employess having low job environment satifaction

sns.lineplot(y= emp_data['EmpEnvironmentSatisfaction'], x = emp_data['PerformanceRating'])

# %%
# Total work experience has outliers 

emp_data['TotalWorkExperienceInYears'].describe()
# Out:
# count    1200.000000
# mean       11.330000
# std         7.797228
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkExperienceInYears, dtype: float64

# %%
sns.boxplot(emp_data['TotalWorkExperienceInYears'])

# %%
ax=sns.countplot(emp_data['TotalWorkExperienceInYears'])
ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)
plt.tight_layout()
plt.show()

# %%
sns.distplot(emp_data['TotalWorkExperienceInYears'])

# %%
emp_data.pivot_table(values = ['Age','EmpJobSatisfaction','EmpEnvironmentSatisfaction','TotalWorkExperienceInYears'], index = [ 'PerformanceRating','EmpDepartment','EmpJobRole'], aggfunc = np.mean).head(40)
# Out:
#                                                                           Age  \
# PerformanceRating EmpDepartment          EmpJobRole
# 2                 Data Science           Data Scientist             40.000000
#                   Development            Developer                  36.833333
#                                          Senior Developer           34.166667
#                                          Technical Lead             31.000000
#                   Finance                Finance Manager            39.466667
#                   Human Resources        Human Resources            37.888889
#                                          Manager                    50.000000
#                   Research & Development Healthcare Representative  40.250000
#                                          Laboratory Technician      32.785714
#                                          Manager R&D                42.058824
# ...

# %%
emp_data.pivot_table(values = ['TotalWorkExperienceInYears'], index = [ 'PerformanceRating','EmpDepartment'], aggfunc = np.mean)
# Out:
#                                           TotalWorkExperienceInYears
# PerformanceRating EmpDepartment
# 2                 Data Science                             22.000000
#                   Development                              13.461538
#                   Finance                                  14.533333
#                   Human Resources                          11.100000
#                   Research & Development                   12.044118
#                   Sales                                    12.977011
# 3                 Data Science                             12.294118
#                   Development                              11.128289
#                   Finance                                   9.133333
#                   Human Resources                          12.210526
#                   Research & Development                   11.645299
#                   Sales                                    10.462151
# ...

# %%
emp_data['EmpDepartment'].value_counts()
# Out:
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: EmpDepartment, dtype: int64

# %%
# Employee Relationship satisfaction

emp_data['EmpRelationshipSatisfaction'].value_counts()
# Out:
# 3    379
# 4    355
# 2    247
# 1    219
# Name: EmpRelationshipSatisfaction, dtype: int64

# %%
sns.countplot(emp_data['EmpRelationshipSatisfaction'])

# %%
emp = ['3', '4','2','1']

data = [379,355,247,219]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp, autopct='%1.2f') 
 
plt.show()

# %%
# How frequently the employee is travelling

emp_data['BusinessTravelFrequency'].value_counts()
# Out:
# Travel_Rarely        846
# Travel_Frequently    222
# Non-Travel           132
# Name: BusinessTravelFrequency, dtype: int64

# %%
sns.countplot(emp_data['BusinessTravelFrequency'])

# %%
emp = ['Trave_Rarely', 'Travel_Frequently','Non-Travel']

data = [846,222,132]
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = emp, autopct='%1.2f') 
 
plt.show()

# %%
# AGE analysis

emp_data['Age'].describe()
# Out:
# count    1200.000000
# mean       36.918333
# std         9.087289
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
sns.distplot(emp_data['Age'])

# %%
sns.boxplot(emp_data['Age'])

# %%
# Maximum number of employees are sales executive and Developer 

# Employee job role

emp_data['EmpJobRole'].value_counts()
# Out:
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: EmpJobRole, dtype: int64

# %%
sns.countplot(emp_data['EmpJobRole'])
# ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)
# plt.tight_layout()
# plt.show()

# %%
# EMPLOYEE DEPARTMENT
# most employees are from Sales, Development and Research & development department

emp_data['EmpDepartment'].value_counts()
# Out:
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: EmpDepartment, dtype: int64

# %%
ax=sns.countplot(emp_data['EmpDepartment'])
ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)
plt.tight_layout()
plt.show()

# %%
emp = ['Sales', 'Development','Research & Development','Human Resources','Finance','Data Science']

data = [373,361,343,54,49,20]
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = emp, autopct='%1.2f') 
 
plt.show()

# %%
#EMPLOYEE JOB LEVEL

# Employee counts are more on level 1 and 2

emp_data['EmpJobLevel'].value_counts()
# Out:
# 2    441
# 1    440
# 3    173
# 4     90
# 5     56
# Name: EmpJobLevel, dtype: int64

# %%
sns.countplot(emp_data['EmpJobLevel'])

# %%
# pie chart for employee job level

emp = ['1', '2','3','4','5']

data = [440,441,173,90,56]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp, autopct='%1.2f') 
 
plt.show()

# %%
# Marital status

emp_data['MaritalStatus'].value_counts()
# Out:
# Married     548
# Single      384
# Divorced    268
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(emp_data['MaritalStatus'])

# %%
emp = ['Single', 'Married','Divorced']

data = [548,384,268]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# Employee Job Satisfaction

emp_data['EmpJobSatisfaction'].value_counts()
# Out:
# 4    378
# 3    354
# 2    237
# 1    231
# Name: EmpJobSatisfaction, dtype: int64

# %%
sns.countplot(emp_data['EmpJobSatisfaction'])

# %%
# Employees with 12,13,14,11 percent hike are higher in number

emp_data['EmpLastSalaryHikePercent'].value_counts()
# Out:
# 14    172
# 11    169
# 13    168
# 12    155
# 15     82
# 18     73
# 16     68
# 17     67
# 19     63
# 20     50
# 22     47
# 21     34
# 23     21
# 24     18
# 25     13
# Name: EmpLastSalaryHikePercent, dtype: int64

# %%
sns.countplot(emp_data['EmpLastSalaryHikePercent'])

# %%
sns.scatterplot(x = emp_data['Age'], y = emp_data['ExperienceYearsAtThisCompany'])

# %%
# Attrition

emp_data['Attrition'].value_counts()
# Out:
# No     1022
# Yes     178
# Name: Attrition, dtype: int64

# %%
sns.countplot(emp_data['Attrition'])

# %%
emp = ['Yes', 'No']

data = [178,1022]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# Education Background

emp_data['EducationBackground'].value_counts()
# Out:
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: EducationBackground, dtype: int64

# %%
ax=sns.countplot(emp_data['EducationBackground'])
ax.set_xticklabels(ax.get_xticklabels(), fontsize=7.5)
plt.tight_layout()
plt.show()

# %%
emp = ['Marketing', 'Life Sciences','Human Resources', 'Medical','Other', 'Technical Degree']

data = [137,492,21,384,66,100]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# Employee Eduction level

emp_data['EmpEducationLevel'].value_counts()
# Out:
# 3    449
# 4    322
# 2    239
# 1    148
# 5     42
# Name: EmpEducationLevel, dtype: int64

# %%
sns.countplot(emp_data['EmpEducationLevel'])

# %%
emp = ['3', '4','2', '1','5']

data = [449,322,239,148,42]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# Employee Environment  Satisfaction

emp_data['EmpEnvironmentSatisfaction'].value_counts()
# Out:
# 3    367
# 4    361
# 2    242
# 1    230
# Name: EmpEnvironmentSatisfaction, dtype: int64

# %%
sns.countplot(emp_data['EmpEnvironmentSatisfaction'])

# %%
emp = ['3','4','2','1']

data = [367,361,242,230]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# EMPLOYEE SATISFACTION LEVEL

emp_data['EmpJobSatisfaction'].value_counts()
# Out:
# 4    378
# 3    354
# 2    237
# 1    231
# Name: EmpJobSatisfaction, dtype: int64

# %%
sns.countplot(emp_data['EmpJobSatisfaction'])

# %%
emp = ['4','3','2','1']

data = [378,354,237,231]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# Employee Job involvement

emp_data['EmpJobInvolvement'].value_counts()
# Out:
# 3    724
# 2    294
# 4    112
# 1     70
# Name: EmpJobInvolvement, dtype: int64

# %%
sns.countplot(emp_data['EmpJobInvolvement'])

# %%
emp = ['3','2','4','1']

data = [724,294,112,70]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# Distance from home

emp_data['DistanceFromHome'].describe()
# Out:
# count    1200.000000
# mean        9.165833
# std         8.176636
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
sns.boxplot(emp_data['DistanceFromHome'])

# %%
sns.distplot(emp_data['DistanceFromHome'])

# %%
# Employee hourly rate

emp_data['EmpHourlyRate'].describe()
# Out:
# count    1200.000000
# mean       65.981667
# std        20.211302
# min        30.000000
# 25%        48.000000
# 50%        66.000000
# 75%        83.000000
# max       100.000000
# Name: EmpHourlyRate, dtype: float64

# %%
sns.distplot(emp_data['EmpHourlyRate'])

# %%
sns.boxplot(emp_data['EmpHourlyRate'])

# %%
# Employee Last Salary Hike Percent

emp_data['EmpLastSalaryHikePercent'].describe()

# emp_data['EmpLastSalaryHikePercent'].value_counts()
# Out:
# count    1200.000000
# mean       15.222500
# std         3.625918
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: EmpLastSalaryHikePercent, dtype: float64

# %%
sns.distplot(emp_data['EmpLastSalaryHikePercent'])

# %%
sns.boxplot(emp_data['EmpLastSalaryHikePercent'])

# %%
# TrainingTimesLastYear

emp_data['TrainingTimesLastYear'].value_counts()
# Out:
# 2    445
# 3    413
# 5     98
# 4     98
# 1     56
# 6     46
# 0     44
# Name: TrainingTimesLastYear, dtype: int64

# %%
sns.countplot(emp_data['TrainingTimesLastYear'])

# %%
emp = ['2','3','5','4','1','6','0']

data = [445,413,98,98,56,46,44]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# ExperienceYearsAtThisCompany

emp_data['ExperienceYearsAtThisCompany'].describe()
# Out:
# count    1200.000000
# mean        7.077500
# std         6.236899
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%        10.000000
# max        40.000000
# Name: ExperienceYearsAtThisCompany, dtype: float64

# %%
sns.distplot(emp_data['ExperienceYearsAtThisCompany'])

# %%
sns.boxplot(emp_data['ExperienceYearsAtThisCompany'])

# %%
# YearsSinceLastPromotion       

emp_data['YearsSinceLastPromotion'].describe()
# Out:
# count    1200.000000
# mean        2.194167
# std         3.221560
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        15.000000
# Name: YearsSinceLastPromotion, dtype: float64

# %%
sns.distplot(emp_data['YearsSinceLastPromotion'])

# %%
sns.boxplot(emp_data['YearsSinceLastPromotion'])

# %%
# PERFORMANCE RATING

emp_data['PerformanceRating'].value_counts()
# Out:
# 3    874
# 2    194
# 4    132
# Name: PerformanceRating, dtype: int64

# %%
sns.countplot(emp_data['PerformanceRating'])

# %%
emp = ['3','2','4']

data = [874,194,132]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# Employee Work Life balance

emp_data['EmpWorkLifeBalance'].value_counts()
# Out:
# 3    727
# 2    294
# 4    115
# 1     64
# Name: EmpWorkLifeBalance, dtype: int64

# %%
sns.countplot(emp_data['EmpWorkLifeBalance'])

# %%
emp = ['3','2','4','1']
data=[727,294,115,64]
fig = plt.figure(figsize =(8, 5)) 
plt.pie(data, labels = emp,autopct='%1.2f') 
plt.show()

# %%
# performance rating vs Exp in current role
# Performance vs year since last promotion
# performance vs years with current manager
# performance vs Employee Work life balance

# plot indicates that performance decreases with increase in exp years in the same role
# plot indicates that the performance descreases with increase in the years since last promotion
# performance descreases with increase in years under same manager
# employee performance increases with increase in work life balance

plt.figure(figsize=(10,7))

plt.subplot(221)
sns.barplot(x=emp_data['PerformanceRating'],y=emp_data['YearsSinceLastPromotion'])

plt.subplot(222)
sns.barplot(x=emp_data['PerformanceRating'],y=emp_data['YearsWithCurrManager'])

plt.subplot(223)
sns.barplot(x=emp_data['PerformanceRating'],y=emp_data['ExperienceYearsInCurrentRole'])

plt.subplot(224)
sns.barplot(x=emp_data['PerformanceRating'],y=emp_data['EmpWorkLifeBalance'])

# plt.subplot(224)
# sns.barplot(x=emp_data['PerformanceRating'],y=emp_data['EmpLastSalaryHikePercent'])

# %%
# Taking the data of the employees with performance rating as '2'

df = emp_data[emp_data['PerformanceRating']==2]
df['PerformanceRating'].value_counts()
# Out:
# 2    194
# Name: PerformanceRating, dtype: int64

# %%
df.pivot_table(values = ['Age','EmpJobSatisfaction','EmpEnvironmentSatisfaction','TotalWorkExperienceInYears','YearsSinceLastPromotion'], index = [ 'PerformanceRating','EmpDepartment','EmpJobRole'], aggfunc = np.mean)
# Out:
#                                                                           Age  \
# PerformanceRating EmpDepartment          EmpJobRole
# 2                 Data Science           Data Scientist             40.000000
#                   Development            Developer                  36.833333
#                                          Senior Developer           34.166667
#                                          Technical Lead             31.000000
#                   Finance                Finance Manager            39.466667
#                   Human Resources        Human Resources            37.888889
#                                          Manager                    50.000000
#                   Research & Development Healthcare Representative  40.250000
#                                          Laboratory Technician      32.785714
#                                          Manager R&D                42.058824
# ...

# %%
fig = px.histogram(emp_data, x='EmpJobRole', y= 'Age',color='PerformanceRating')
fig.show()
# Out:
# <div>                            <div id="2e748c17-339b-4750-8614-ee52da1c6705" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e748c17-339b-4750-8614-ee52da1c6705")) {                    Plotly.newPlot(                        "2e748c17-339b-4750-8614-ee52da1c6705",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "PerformanceRating=3<br>EmpJobRole=%{x}<br>sum of Age=%{y}<extra></extra>", "legendgroup": "3", "marker": {"color": "#636efa"}, "name": "3", "offsetgroup": "3", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Sales Executive", "Sales Executive", "Manager", "Sales Executive", "Sales Representative", "Developer", "Developer", "Developer", "Developer", "Sales Executiv
# ...

# %%
ax=sns.barplot(x=emp_data['EmpDepartment'], y=emp_data['YearsSinceLastPromotion'],hue=emp_data['PerformanceRating'])

ax.set_xticklabels(ax.get_xticklabels(), fontsize=6)
plt.tight_layout()
plt.show()

# %%
ax=sns.barplot(x=emp_data['EmpDepartment'], y=emp_data['YearsSinceLastPromotion'],hue=emp_data['Gender'])

ax.set_xticklabels(ax.get_xticklabels(), fontsize=6)
plt.tight_layout()
plt.show()

# %%
ax=sns.barplot(x=emp_data['EmpDepartment'], y=emp_data['EmpLastSalaryHikePercent'],hue=emp_data['PerformanceRating'])

ax.set_xticklabels(ax.get_xticklabels(), fontsize=6)
plt.tight_layout()
plt.show()

# %%
ax=sns.barplot(x=emp_data['EmpDepartment'], y=emp_data['YearsWithCurrManager'],hue=emp_data['PerformanceRating'])

ax.set_xticklabels(ax.get_xticklabels(), fontsize=6)
plt.tight_layout()
plt.show()

# %%
ax=sns.barplot(x=df['EmpDepartment'], y=df['YearsWithCurrManager'],hue=df['PerformanceRating'])

ax.set_xticklabels(ax.get_xticklabels(), fontsize=6)
plt.tight_layout()
plt.show()

# %%
ax=sns.barplot(x=df['EmpDepartment'], y=df['TrainingTimesLastYear'],hue=df['PerformanceRating'])

ax.set_xticklabels(ax.get_xticklabels(), fontsize=6)
plt.tight_layout()
plt.show()

# %%
ax=sns.barplot(x=emp_data['EmpDepartment'], y=emp_data['TrainingTimesLastYear'],hue=emp_data['PerformanceRating'])

ax.set_xticklabels(ax.get_xticklabels(), fontsize=6)
plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000         -0.030277           0.204028
# DistanceFromHome             -0.030277          1.000000           0.103505
# EmpEducationLevel             0.204028          0.103505           1.000000
# EmpEnvironmentSatisfaction   -0.021045          0.095346          -0.064854
# EmpHourlyRate                 0.190302         -0.006688          -0.040018
# EmpJobInvolvement             0.180085         -0.129792           0.047790
# EmpJobLevel                   0.440019         -0.081609           0.092024
# EmpJobSatisfaction            0.022414         -0.072503          -0.116233
# NumCompaniesWorked            0.215244         -0.099737           0.066062
# EmpLastSalaryHikePercent      0.091668          0.065728           0.078990
# EmpRelationshipSatisfaction   0.117896         -0.013526          -0.010773
# ...

# %%
df['EmpDepartment'].value_counts()
# Out:
# Sales                     87
# Research & Development    68
# Finance                   15
# Development               13
# Human Resources           10
# Data Science               1
# Name: EmpDepartment, dtype: int64

# %%
import plotly.express as px 
fig = px.sunburst(emp_data, path=['PerformanceRating','EmpDepartment','EmpJobRole'] ) 
fig.show()

fig = px.sunburst(df, path=['PerformanceRating','EmpDepartment','Gender','EmpJobRole'] ) 
fig.show()
# Out:
# <div>                            <div id="ddff60f3-f0b7-4962-a528-a674d223f0bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddff60f3-f0b7-4962-a528-a674d223f0bf")) {                    Plotly.newPlot(                        "ddff60f3-f0b7-4962-a528-a674d223f0bf",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["3/Development/Business Analyst", "4/Development/Business Analyst", "2/Data Science/Data Scientist", "3/Data Science/Data Scientist", "4/Data Science/Data Scientist", "3/Development/Delivery Manager", "2/Development/Developer", "3/Development/Developer", "4/Development/Developer", "2/F
# ...

# %%
# Based on Marital status

fig = px.sunburst(df, path=['PerformanceRating','EmpDepartment','Gender','MaritalStatus','EmpJobRole'] ) 
fig.show()
# Out:
# <div>                            <div id="f2c5524a-784d-4664-93c6-2bf0bca64fa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2c5524a-784d-4664-93c6-2bf0bca64fa0")) {                    Plotly.newPlot(                        "f2c5524a-784d-4664-93c6-2bf0bca64fa0",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["2/Data Science/Male/Divorced/Data Scientist", "2/Development/Male/Divorced/Developer", "2/Development/Male/Married/Developer", "2/Development/Female/Single/Developer", "2/Finance/Female/Divorced/Finance Manager", "2/Finance/Male/Divorced/Finance Manager", "2/Finance/Female/Married/Fin
# ...

# %%
fig = px.box(emp_data,x='EmpJobRole', y='Age')
fig.show()
# Out:
# <div>                            <div id="a3115697-38e4-4c7f-b135-a81275db3d65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3115697-38e4-4c7f-b135-a81275db3d65")) {                    Plotly.newPlot(                        "a3115697-38e4-4c7f-b135-a81275db3d65",                        [{"alignmentgroup": "True", "hovertemplate": "EmpJobRole=%{x}<br>Age=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Sales Executive", "Sales Executive", "Sales Executive", "Manager", "Sales Executive", "Developer", "Sales Representative", "Developer", "Developer", "Developer", "Developer", "Sales Executive", "Sales Executive", "
# ...

# %%
fig =px.bar(emp_data,x='EmpDepartment', color='PerformanceRating', y='ExperienceYearsInCurrentRole')
fig.show()

fig =px.bar(emp_data,x='EmpJobRole', y='YearsSinceLastPromotion',color='PerformanceRating')
fig.show()
# Out:
# <div>                            <div id="64275c7c-20d2-4194-9a43-32aba28d838b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64275c7c-20d2-4194-9a43-32aba28d838b")) {                    Plotly.newPlot(                        "64275c7c-20d2-4194-9a43-32aba28d838b",                        [{"alignmentgroup": "True", "hovertemplate": "EmpDepartment=%{x}<br>ExperienceYearsInCurrentRole=%{y}<br>PerformanceRating=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
# ...

# %%
sns.swarmplot(x='PerformanceRating', y='Age', data=emp_data,hue='EmpDepartment',palette='Set1',dodge=True)

# %%
sns.swarmplot(x='PerformanceRating', y='Age', data=df,hue='EmpDepartment',palette='Set1',dodge=True)

# %%
sns.catplot(x='Age', y='EmpDepartment', data=emp_data,hue='PerformanceRating',palette='Set1',dodge=True, kind="swarm")

# %%
sns.catplot(x='Age', y='EmpJobRole', data=emp_data,hue='PerformanceRating',palette='Set1',dodge=True, kind="swarm")

# %%
sns.swarmplot(x='PerformanceRating', y='Age', data=emp_data,hue='MaritalStatus',palette='Set1',dodge=True)

# %%
sns.catplot(x='PerformanceRating', y='Age', data=emp_data,hue='MaritalStatus',palette='Set1',kind="swarm",dodge=True)

# %%
sns.swarmplot(x='PerformanceRating', y='Age', data=emp_data,hue='Gender',palette='Set1',dodge=True)

# %%
htmp = df.corr()
htmp
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000         -0.030277           0.204028
# DistanceFromHome             -0.030277          1.000000           0.103505
# EmpEducationLevel             0.204028          0.103505           1.000000
# EmpEnvironmentSatisfaction   -0.021045          0.095346          -0.064854
# EmpHourlyRate                 0.190302         -0.006688          -0.040018
# EmpJobInvolvement             0.180085         -0.129792           0.047790
# EmpJobLevel                   0.440019         -0.081609           0.092024
# EmpJobSatisfaction            0.022414         -0.072503          -0.116233
# NumCompaniesWorked            0.215244         -0.099737           0.066062
# EmpLastSalaryHikePercent      0.091668          0.065728           0.078990
# EmpRelationshipSatisfaction   0.117896         -0.013526          -0.010773
# ...

# %%
sns.heatmap(htmp, cmap='OrRd')
